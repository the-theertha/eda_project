# %%
import pandas as pd # data handeling
import numpy as np # working with arrays
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns # for plotting advance graphs

# %%
df = pd.read_csv("co2.csv") # reading data from a csv file

# %%
df.head(3) # watcing the first few rows of data
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
#
#                            Indicator Name      1990      1991      1992  \
# 0  CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# 2  CO2 emissions (metric tons per capita)  0.553662  0.544539  0.543557
#
#        1993      1994      1995  ...      2011      2012      2013      2014  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1  0.084721  0.075546  0.068468  ...  0.296506  0.259295  0.185624  0.146236
# 2  0.708984  0.836804  0.912141  ...  0.985522  0.950696  1.036294  1.099779
#
#        2015      2016      2017      2018      2019    2019.1
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df['Country Name'].nunique() # checking all unique country names
# Out:
# 215

# %%
df.isnull().sum() # finding all null values
# Out:
# country_name       0
# country_code       0
# region             0
# indicator_name     0
# 1990              30
# 1991              29
# 1992              26
# 1993              26
# 1994              26
# 1995              25
# 1996              25
# 1997              25
# 1998              26
# 1999              26
# 2000              25
# 2001              25
# 2002              24
# 2003              24
# 2004              24
# 2005              24
# 2006              24
# 2007              24
# 2008              24
# 2009              24
# 2010              24
# 2011              24
# 2012              24
# 2013              24
# 2014              24
# 2015              24
# 2016              24
# 2017              24
# 2018              24
# 2019              24
# 2019.1            24
# dtype: int64

# %%
df.describe() # looking at all the stats. analysis
# Out:
#              1990        1991        1992        1993        1994        1995  \
# count  185.000000  186.000000  189.000000  189.000000  189.000000  190.000000
# mean     4.404504    4.290648    4.174834    4.085472    4.045067    4.136628
# std      5.577460    5.577411    5.362451    5.385712    5.464233    5.510400
# min      0.001183    0.001158    0.001130    0.001100    0.001071    0.001043
# 25%      0.434249    0.452759    0.471380    0.448535    0.406659    0.423225
# 50%      1.914543    1.941825    2.012212    1.867589    1.830972    1.832534
# 75%      6.910335    6.497471    6.482311    6.430944    6.337175    6.360589
# max     30.195189   31.778496   29.632441   33.122025   36.466263   37.102174
#
#              1996        1997        1998        1999  ...        2011  \
# count  190.000000  190.000000  189.000000  189.000000  ...  191.000000
# mean     4.211147    4.250716    4.282809    4.265652  ...    4.392175
# ...

# %%
# renaming all cloumns according to convention
df.rename(columns={
    'Country Name':'country_name', 
    'Region':'region', 
    'Indicator Name':'indicator_name'},
              inplace=True)

# %%
df # checking if all columns are renamed
# Out:
#      country_name country_code                      region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              indicator_name      1990      1991      1992  \
# 0    CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1    CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# ...

# %%
co2_emission.dropna(inplace = True) # Dropping all null values beacuse fixing them will produce variance in data
# Out:
# 3

# %%
info = df.iloc[:,0:4] # picking all info cols.
info
# Out:
#      country_name country_code                      region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              indicator_name
# 0    CO2 emissions (metric tons per capita)
# 1    CO2 emissions (metric tons per capita)
# 2    CO2 emissions (metric tons per capita)
# 3    CO2 emissions (metric tons per capita)
# ...

# %%
co2_emission = df.iloc[:,4:] # picking all co2_emission cols.
co2_emission
# Out:
#          1990      1991      1992      1993      1994      1995      1996  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.191745  0.167682  0.095958  0.084721  0.075546  0.068468  0.062588
# 2    0.553662  0.544539  0.543557  0.708984  0.836804  0.912141  1.072168
# 3    1.819542  1.242810  0.683700  0.638307  0.645355  0.605436  0.612367
# 4    7.521832  7.235379  6.963079  6.724178  6.541579  6.733479  6.991595
# ..        ...       ...       ...       ...       ...       ...       ...
# 210  0.552836  0.609756  0.604266  0.658221  0.592807  0.705675  0.759501
# 211  0.567037  0.690937  0.704793  0.627105  0.653256  0.706081  0.698158
# 212  6.729799  6.424622  6.175430  6.219194  6.215847  6.378790  6.489192
# 213  0.340930  0.349232  0.337224  0.289956  0.241270  0.234153  0.188442
# 214  1.585444  1.713321  1.694416  1.539741  1.417186  1.356619  1.287559
#
#          1997      1998      1999  ...      2011      2012      2013  \
# ...

# %%
co2_emission.index = df['country_name'] # getting country names and index
co2_emission
# Out:
#                   1990      1991      1992      1993      1994      1995  \
# country_name
# Aruba              NaN       NaN       NaN       NaN       NaN       NaN
# Afghanistan   0.191745  0.167682  0.095958  0.084721  0.075546  0.068468
# Angola        0.553662  0.544539  0.543557  0.708984  0.836804  0.912141
# Albania       1.819542  1.242810  0.683700  0.638307  0.645355  0.605436
# Andorra       7.521832  7.235379  6.963079  6.724178  6.541579  6.733479
# ...                ...       ...       ...       ...       ...       ...
# Samoa         0.552836  0.609756  0.604266  0.658221  0.592807  0.705675
# Yemen, Rep.   0.567037  0.690937  0.704793  0.627105  0.653256  0.706081
# South Africa  6.729799  6.424622  6.175430  6.219194  6.215847  6.378790
# Zambia        0.340930  0.349232  0.337224  0.289956  0.241270  0.234153
# Zimbabwe      1.585444  1.713321  1.694416  1.539741  1.417186  1.356619
#
# ...

# %%
co2_emission.dropna(inplace = True) # Dropping all na values in co2_emission

# %%
co2_emission.iloc[:,-1]
# Out:
# country_name
# Afghanistan              0.159824
# Angola                   0.792137
# Albania                  1.692248
# Andorra                  6.481217
# United Arab Emirates    19.329563
#                           ...
# Samoa                    1.522124
# Yemen, Rep.              0.380633
# South Africa             7.507736
# Zambia                   0.380717
# Zimbabwe                 0.802979
# Name: 2019.1, Length: 183, dtype: float64

# %%
co2_emission = co2_emission.sort_values(by = '2019', ascending = False) # sorting all co2_emission by descending order

# %%
# Plotting all countries with their co2_emissions data

sns.set_theme(style = 'darkgrid')
ax = plt.subplots(figsize=(10,35))
sns.set_color_codes('pastel')

#Plotting graph using seaborn for co2 emission 
sns.barplot(y = co2_emission.index,
            x = co2_emission['2019'])
plt.xlabel('CO2 Emission (metric ton per capita)')
plt.ylabel('Country')
plt.title("CO2 emission by countries in 2019")
# Out:
# Text(0.5, 1.0, 'CO2 emission by countries in 2019')

# %%
"""
Getting Top 5 Countries having peak c02 emissions and plotting their history of emissions.
"""

co2_emission['avg'] = co2_emission.mean(axis = 1)
co2_avg = co2_emission.sort_values('avg', ascending = False).head(5)

#Drop 'avg' column 
co2_avg = co2_avg.drop('avg', axis = 'columns')

#Plot time-series linegraph
fig, ax = plt.subplots(figsize =(20, 10))
n = 0
while n <5:
    sns.lineplot( x = co2_avg.columns, y = co2_avg.iloc[n], label = co2_avg.index[n])
    n+=1

plt.xlabel("Year")
plt.ylabel("CO2 Emission (metric ton per capita)")
plt.title("Top 5 Highest Average CO2 Emission per Capita Over Time")
# Out:
# Text(0.5, 1.0, 'Top 5 Highest Average CO2 Emission per Capita Over Time')

# %%
##
- Qatar was having highest co2 emission in 1999
